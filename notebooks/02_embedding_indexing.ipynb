# %% [markdown]
# # Task 2: Text Chunking, Embedding, and Vector Store Indexing
#
# This notebook processes cleaned complaint narratives, generates embeddings, and indexes them in a ChromaDB vector store with persistence. It uses LangChain's RecursiveCharacterTextSplitter for chunking.
#
# **Objectives**:
# - Chunk cleaned narratives from `filtered_complaints.csv` using RecursiveCharacterTextSplitter
# - Generate embeddings using SentenceTransformers
# - Index embeddings and metadata (Complaint ID, Mapped_Product) in a persistent ChromaDB store
#
# **File Paths**:
# - Input: `data/processed/filtered_complaints.csv`
# - Output: ChromaDB collection in `data/embeddings/`

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import logging
from sentence_transformers import SentenceTransformer
import chromadb
from langchain.text_splitter import RecursiveCharacterTextSplitter
# Optional utility module for chunking and embedding (not used in this run)
# from embedding_utils import chunk_text, generate_embeddings
# Setup logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Load pre-trained model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Define paths
# Get the path to the current notebook file
# If running directly in a .py file, use Path(__file__).parent
# For Jupyter notebooks, Path.cwd() often works for the notebook's directory.
# Then, go up one level to reach the project root.
PROJECT_ROOT = Path.cwd().parent


CSV_PATH = PROJECT_ROOT / 'data' / 'processed' / 'filtered_complaints.csv'
EMBEDDINGS_DIR = PROJECT_ROOT / 'data' / 'embeddings'
EMBEDDINGS_DIR.mkdir(parents=True, exist_ok=True)

print(f"Input CSV: {CSV_PATH}")
print(f"Output directory: {EMBEDDINGS_DIR}")
# Out:
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: cpu
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: all-MiniLM-L6-v2
# Input CSV: c:\Users\hp\Desktop\projects\10 Acadamy -KAIM5\financial-complaint-chatbot\data\processed\filtered_complaints.csv
# Output directory: c:\Users\hp\Desktop\projects\10 Acadamy -KAIM5\financial-complaint-chatbot\data\embeddings

# %%
# Load and process data
df = pd.read_csv(CSV_PATH)
if 'Cleaned_Narrative' not in df.columns or 'Complaint ID' not in df.columns or 'Mapped_Product' not in df.columns:
    logger.error("Required columns (Cleaned_Narrative, Complaint ID, Mapped_Product) not found in CSV")
else:
    # Initialize RecursiveCharacterTextSplitter
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=512,
        chunk_overlap=50,
        length_function=len,
        add_start_index=True
    )
    
    # Chunk narratives and associate with metadata
    all_chunks = []
    chunk_metadata = []
    for idx, row in df.iterrows():
        chunks = text_splitter.split_text(row['Cleaned_Narrative'])
        for chunk in chunks:
            all_chunks.append(chunk)
            chunk_metadata.append({
                'complaint_id': row['Complaint ID'],
                'mapped_product': row['Mapped_Product']
            })
    
    # Generate embeddings
    embeddings = model.encode(all_chunks, convert_to_numpy=True)
    
    if len(all_chunks) == 0 or embeddings.size == 0:
        logger.error("No chunks or embeddings generated")
    else:
        logger.info(f"Generated {len(all_chunks)} chunks and {embeddings.shape[0]} embeddings")
        print(f"First chunk: {all_chunks[0][:100]}...")
        print(f"Embedding shape: {embeddings.shape}")  # Should be (n_chunks, 384) for all-MiniLM-L6-v2
# Out:
# Batches:   0%|          | 0/24073 [00:00<?, ?it/s]
# INFO:__main__:Generated 770308 chunks and 770308 embeddings
# First chunk: apt transunion consumer solutions security freeze request dear sir madam social security resident su...
# Embedding shape: (770308, 384)

# %%
# Initialize PersistentClient and create collection
client = chromadb.PersistentClient(path=str(EMBEDDINGS_DIR))
collection = client.get_or_create_collection(name="complaint_embeddings", metadata={"hnsw:space": "cosine"})

# Define a batch size, well within ChromaDB's limit (e.g., 5000 or less)
batch_size = 5000 # You can adjust this, but keep it below the max_batch_size (5461)

# Get the total number of chunks/embeddings
total_chunks = len(all_chunks)

# Add embeddings, chunks, and metadata to ChromaDB in batches
for i in range(0, total_chunks, batch_size):
    # Determine the end index for the current batch
    end_index = min(i + batch_size, total_chunks)

    # Slice the data for the current batch
    batch_embeddings = embeddings[i:end_index].tolist()
    batch_documents = all_chunks[i:end_index]
    batch_metadatas = chunk_metadata[i:end_index]
    batch_ids = [f"chunk_{j}" for j in range(i, end_index)]

    logger.info(f"Adding batch {i//batch_size + 1}/{(total_chunks + batch_size - 1)//batch_size} (from index {i} to {end_index-1})...")
    collection.add(
        embeddings=batch_embeddings,
        documents=batch_documents,
        metadatas=batch_metadatas,
        ids=batch_ids
    )
    logger.info(f"Batch {i//batch_size + 1} added. Current total vectors: {collection.count()}")


logger.info(f"Indexed {collection.count()} vectors in ChromaDB")
print(f"Total vectors in collection: {collection.count()}")
# Out:
# INFO:__main__:Adding batch 1/155 (from index 0 to 4999)...
# INFO:__main__:Batch 1 added. Current total vectors: 5000
# INFO:__main__:Adding batch 2/155 (from index 5000 to 9999)...
# INFO:__main__:Batch 2 added. Current total vectors: 10000
# INFO:__main__:Adding batch 3/155 (from index 10000 to 14999)...
# INFO:__main__:Batch 3 added. Current total vectors: 15000
# INFO:__main__:Adding batch 4/155 (from index 15000 to 19999)...
# INFO:__main__:Batch 4 added. Current total vectors: 20000
# INFO:__main__:Adding batch 5/155 (from index 20000 to 24999)...
# INFO:__main__:Batch 5 added. Current total vectors: 25000
# INFO:__main__:Adding batch 6/155 (from index 25000 to 29999)...
# INFO:__main__:Batch 6 added. Current total vectors: 30000
# INFO:__main__:Adding batch 7/155 (from index 30000 to 34999)...
# INFO:__main__:Batch 7 added. Current total vectors: 35000
# INFO:__main__:Adding batch 8/155 (from index 35000 to 39999)...
# INFO:__main__:Batch 8 added. Current total vectors: 40000
# INFO:__main__:Adding batch 9/155 (from index 40000 to 44999)...
# INFO:__main__:Batch 9 added. Current total vectors: 45000
# INFO:__main__:Adding batch 10/155 (from index 45000 to 49999)...
# INFO:__main__:Batch 10 added. Current total vectors: 50000
# INFO:__main__:Adding batch 11/155 (from index 50000 to 54999)...
# INFO:__main__:Batch 11 added. Current total vectors: 55000
# INFO:__main__:Adding batch 12/155 (from index 55000 to 59999)...
# INFO:__main__:Batch 12 added. Current total vectors: 60000
# INFO:__main__:Adding batch 13/155 (from index 60000 to 64999)...
# INFO:__main__:Batch 13 added. Current total vectors: 65000
# INFO:__main__:Adding batch 14/155 (from index 65000 to 69999)...
# INFO:__main__:Batch 14 added. Current total vectors: 70000
# INFO:__main__:Adding batch 15/155 (from index 70000 to 74999)...
# INFO:__main__:Batch 15 added. Current total vectors: 75000
# INFO:__main__:Adding batch 16/155 (from index 75000 to 79999)...
# INFO:__main__:Batch 16 added. Current total vectors: 80000
# INFO:__main__:Adding batch 17/155 (from index 80000 to 84999)...
# INFO:__main__:Batch 17 added. Current total vectors: 85000
# INFO:__main__:Adding batch 18/155 (from index 85000 to 89999)...
# INFO:__main__:Batch 18 added. Current total vectors: 90000
# INFO:__main__:Adding batch 19/155 (from index 90000 to 94999)...
# INFO:__main__:Batch 19 added. Current total vectors: 95000
# INFO:__main__:Adding batch 20/155 (from index 95000 to 99999)...
# INFO:__main__:Batch 20 added. Current total vectors: 100000
# INFO:__main__:Adding batch 21/155 (from index 100000 to 104999)...
# INFO:__main__:Batch 21 added. Current total vectors: 105000
# INFO:__main__:Adding batch 22/155 (from index 105000 to 109999)...
# INFO:__main__:Batch 22 added. Current total vectors: 110000
# INFO:__main__:Adding batch 23/155 (from index 110000 to 114999)...
# INFO:__main__:Batch 23 added. Current total vectors: 115000
# INFO:__main__:Adding batch 24/155 (from index 115000 to 119999)...
# INFO:__main__:Batch 24 added. Current total vectors: 120000
# INFO:__main__:Adding batch 25/155 (from index 120000 to 124999)...
# INFO:__main__:Batch 25 added. Current total vectors: 125000
# INFO:__main__:Adding batch 26/155 (from index 125000 to 129999)...
# INFO:__main__:Batch 26 added. Current total vectors: 130000
# INFO:__main__:Adding batch 27/155 (from index 130000 to 134999)...
# INFO:__main__:Batch 27 added. Current total vectors: 135000
# INFO:__main__:Adding batch 28/155 (from index 135000 to 139999)...
# INFO:__main__:Batch 28 added. Current total vectors: 140000
# INFO:__main__:Adding batch 29/155 (from index 140000 to 144999)...
# INFO:__main__:Batch 29 added. Current total vectors: 145000
# INFO:__main__:Adding batch 30/155 (from index 145000 to 149999)...
# INFO:__main__:Batch 30 added. Current total vectors: 150000
# INFO:__main__:Adding batch 31/155 (from index 150000 to 154999)...
# INFO:__main__:Batch 31 added. Current total vectors: 155000
# INFO:__main__:Adding batch 32/155 (from index 155000 to 159999)...
# INFO:__main__:Batch 32 added. Current total vectors: 160000
# INFO:__main__:Adding batch 33/155 (from index 160000 to 164999)...
# INFO:__main__:Batch 33 added. Current total vectors: 165000
# INFO:__main__:Adding batch 34/155 (from index 165000 to 169999)...
# INFO:__main__:Batch 34 added. Current total vectors: 170000
# INFO:__main__:Adding batch 35/155 (from index 170000 to 174999)...
# INFO:__main__:Batch 35 added. Current total vectors: 175000
# INFO:__main__:Adding batch 36/155 (from index 175000 to 179999)...
# INFO:__main__:Batch 36 added. Current total vectors: 180000
# INFO:__main__:Adding batch 37/155 (from index 180000 to 184999)...
# INFO:__main__:Batch 37 added. Current total vectors: 185000
# INFO:__main__:Adding batch 38/155 (from index 185000 to 189999)...
# INFO:__main__:Batch 38 added. Current total vectors: 190000
# INFO:__main__:Adding batch 39/155 (from index 190000 to 194999)...
# INFO:__main__:Batch 39 added. Current total vectors: 195000
# INFO:__main__:Adding batch 40/155 (from index 195000 to 199999)...
# INFO:__main__:Batch 40 added. Current total vectors: 200000
# INFO:__main__:Adding batch 41/155 (from index 200000 to 204999)...
# INFO:__main__:Batch 41 added. Current total vectors: 205000
# INFO:__main__:Adding batch 42/155 (from index 205000 to 209999)...
# INFO:__main__:Batch 42 added. Current total vectors: 210000
# INFO:__main__:Adding batch 43/155 (from index 210000 to 214999)...
# INFO:__main__:Batch 43 added. Current total vectors: 215000
# INFO:__main__:Adding batch 44/155 (from index 215000 to 219999)...
# INFO:__main__:Batch 44 added. Current total vectors: 220000
# INFO:__main__:Adding batch 45/155 (from index 220000 to 224999)...
# INFO:__main__:Batch 45 added. Current total vectors: 225000
# INFO:__main__:Adding batch 46/155 (from index 225000 to 229999)...
# INFO:__main__:Batch 46 added. Current total vectors: 230000
# INFO:__main__:Adding batch 47/155 (from index 230000 to 234999)...
# INFO:__main__:Batch 47 added. Current total vectors: 235000
# INFO:__main__:Adding batch 48/155 (from index 235000 to 239999)...
# INFO:__main__:Batch 48 added. Current total vectors: 240000
# INFO:__main__:Adding batch 49/155 (from index 240000 to 244999)...
# INFO:__main__:Batch 49 added. Current total vectors: 245000
# INFO:__main__:Adding batch 50/155 (from index 245000 to 249999)...
# INFO:__main__:Batch 50 added. Current total vectors: 250000
# INFO:__main__:Adding batch 51/155 (from index 250000 to 254999)...
# INFO:__main__:Batch 51 added. Current total vectors: 255000
# INFO:__main__:Adding batch 52/155 (from index 255000 to 259999)...
# INFO:__main__:Batch 52 added. Current total vectors: 260000
# INFO:__main__:Adding batch 53/155 (from index 260000 to 264999)...
# INFO:__main__:Batch 53 added. Current total vectors: 265000
# INFO:__main__:Adding batch 54/155 (from index 265000 to 269999)...
# INFO:__main__:Batch 54 added. Current total vectors: 270000
# INFO:__main__:Adding batch 55/155 (from index 270000 to 274999)...
# INFO:__main__:Batch 55 added. Current total vectors: 275000
# INFO:__main__:Adding batch 56/155 (from index 275000 to 279999)...
# INFO:__main__:Batch 56 added. Current total vectors: 280000
# INFO:__main__:Adding batch 57/155 (from index 280000 to 284999)...
# INFO:__main__:Batch 57 added. Current total vectors: 285000
# INFO:__main__:Adding batch 58/155 (from index 285000 to 289999)...
# INFO:__main__:Batch 58 added. Current total vectors: 290000
# INFO:__main__:Adding batch 59/155 (from index 290000 to 294999)...
# INFO:__main__:Batch 59 added. Current total vectors: 295000
# INFO:__main__:Adding batch 60/155 (from index 295000 to 299999)...
# INFO:__main__:Batch 60 added. Current total vectors: 300000
# INFO:__main__:Adding batch 61/155 (from index 300000 to 304999)...
# INFO:__main__:Batch 61 added. Current total vectors: 305000
# INFO:__main__:Adding batch 62/155 (from index 305000 to 309999)...
# INFO:__main__:Batch 62 added. Current total vectors: 310000
# INFO:__main__:Adding batch 63/155 (from index 310000 to 314999)...
# INFO:__main__:Batch 63 added. Current total vectors: 315000
# INFO:__main__:Adding batch 64/155 (from index 315000 to 319999)...
# INFO:__main__:Batch 64 added. Current total vectors: 320000
# INFO:__main__:Adding batch 65/155 (from index 320000 to 324999)...
# INFO:__main__:Batch 65 added. Current total vectors: 325000
# INFO:__main__:Adding batch 66/155 (from index 325000 to 329999)...
# INFO:__main__:Batch 66 added. Current total vectors: 330000
# INFO:__main__:Adding batch 67/155 (from index 330000 to 334999)...
# INFO:__main__:Batch 67 added. Current total vectors: 335000
# INFO:__main__:Adding batch 68/155 (from index 335000 to 339999)...
# INFO:__main__:Batch 68 added. Current total vectors: 340000
# INFO:__main__:Adding batch 69/155 (from index 340000 to 344999)...
# INFO:__main__:Batch 69 added. Current total vectors: 345000
# INFO:__main__:Adding batch 70/155 (from index 345000 to 349999)...
# INFO:__main__:Batch 70 added. Current total vectors: 350000
# INFO:__main__:Adding batch 71/155 (from index 350000 to 354999)...
# INFO:__main__:Batch 71 added. Current total vectors: 355000
# INFO:__main__:Adding batch 72/155 (from index 355000 to 359999)...
# INFO:__main__:Batch 72 added. Current total vectors: 360000
# INFO:__main__:Adding batch 73/155 (from index 360000 to 364999)...
# INFO:__main__:Batch 73 added. Current total vectors: 365000
# INFO:__main__:Adding batch 74/155 (from index 365000 to 369999)...
# INFO:__main__:Batch 74 added. Current total vectors: 370000
# INFO:__main__:Adding batch 75/155 (from index 370000 to 374999)...
# INFO:__main__:Batch 75 added. Current total vectors: 375000
# INFO:__main__:Adding batch 76/155 (from index 375000 to 379999)...
# INFO:__main__:Batch 76 added. Current total vectors: 380000
# INFO:__main__:Adding batch 77/155 (from index 380000 to 384999)...
# INFO:__main__:Batch 77 added. Current total vectors: 385000
# INFO:__main__:Adding batch 78/155 (from index 385000 to 389999)...
# INFO:__main__:Batch 78 added. Current total vectors: 390000
# INFO:__main__:Adding batch 79/155 (from index 390000 to 394999)...
# INFO:__main__:Batch 79 added. Current total vectors: 395000
# INFO:__main__:Adding batch 80/155 (from index 395000 to 399999)...
# INFO:__main__:Batch 80 added. Current total vectors: 400000
# INFO:__main__:Adding batch 81/155 (from index 400000 to 404999)...
# INFO:__main__:Batch 81 added. Current total vectors: 405000
# INFO:__main__:Adding batch 82/155 (from index 405000 to 409999)...
# INFO:__main__:Batch 82 added. Current total vectors: 410000
# INFO:__main__:Adding batch 83/155 (from index 410000 to 414999)...
# INFO:__main__:Batch 83 added. Current total vectors: 415000
# INFO:__main__:Adding batch 84/155 (from index 415000 to 419999)...
# INFO:__main__:Batch 84 added. Current total vectors: 420000
# INFO:__main__:Adding batch 85/155 (from index 420000 to 424999)...
# INFO:__main__:Batch 85 added. Current total vectors: 425000
# INFO:__main__:Adding batch 86/155 (from index 425000 to 429999)...
# INFO:__main__:Batch 86 added. Current total vectors: 430000
# INFO:__main__:Adding batch 87/155 (from index 430000 to 434999)...
# INFO:__main__:Batch 87 added. Current total vectors: 435000
# INFO:__main__:Adding batch 88/155 (from index 435000 to 439999)...
# INFO:__main__:Batch 88 added. Current total vectors: 440000
# INFO:__main__:Adding batch 89/155 (from index 440000 to 444999)...
# INFO:__main__:Batch 89 added. Current total vectors: 445000
# INFO:__main__:Adding batch 90/155 (from index 445000 to 449999)...
# INFO:__main__:Batch 90 added. Current total vectors: 450000
# INFO:__main__:Adding batch 91/155 (from index 450000 to 454999)...
# INFO:__main__:Batch 91 added. Current total vectors: 455000
# INFO:__main__:Adding batch 92/155 (from index 455000 to 459999)...
# INFO:__main__:Batch 92 added. Current total vectors: 460000
# INFO:__main__:Adding batch 93/155 (from index 460000 to 464999)...
# INFO:__main__:Batch 93 added. Current total vectors: 465000
# INFO:__main__:Adding batch 94/155 (from index 465000 to 469999)...
# INFO:__main__:Batch 94 added. Current total vectors: 470000
# INFO:__main__:Adding batch 95/155 (from index 470000 to 474999)...
# INFO:__main__:Batch 95 added. Current total vectors: 475000
# INFO:__main__:Adding batch 96/155 (from index 475000 to 479999)...
# INFO:__main__:Batch 96 added. Current total vectors: 480000
# INFO:__main__:Adding batch 97/155 (from index 480000 to 484999)...
# INFO:__main__:Batch 97 added. Current total vectors: 485000
# INFO:__main__:Adding batch 98/155 (from index 485000 to 489999)...
# INFO:__main__:Batch 98 added. Current total vectors: 490000
# INFO:__main__:Adding batch 99/155 (from index 490000 to 494999)...
# INFO:__main__:Batch 99 added. Current total vectors: 495000
# INFO:__main__:Adding batch 100/155 (from index 495000 to 499999)...
# INFO:__main__:Batch 100 added. Current total vectors: 500000
# INFO:__main__:Adding batch 101/155 (from index 500000 to 504999)...
# INFO:__main__:Batch 101 added. Current total vectors: 505000
# INFO:__main__:Adding batch 102/155 (from index 505000 to 509999)...
# INFO:__main__:Batch 102 added. Current total vectors: 510000
# INFO:__main__:Adding batch 103/155 (from index 510000 to 514999)...
# INFO:__main__:Batch 103 added. Current total vectors: 515000
# INFO:__main__:Adding batch 104/155 (from index 515000 to 519999)...
# INFO:__main__:Batch 104 added. Current total vectors: 520000
# INFO:__main__:Adding batch 105/155 (from index 520000 to 524999)...
# INFO:__main__:Batch 105 added. Current total vectors: 525000
# INFO:__main__:Adding batch 106/155 (from index 525000 to 529999)...
# INFO:__main__:Batch 106 added. Current total vectors: 530000
# INFO:__main__:Adding batch 107/155 (from index 530000 to 534999)...
# INFO:__main__:Batch 107 added. Current total vectors: 535000
# INFO:__main__:Adding batch 108/155 (from index 535000 to 539999)...
# INFO:__main__:Batch 108 added. Current total vectors: 540000
# INFO:__main__:Adding batch 109/155 (from index 540000 to 544999)...
# INFO:__main__:Batch 109 added. Current total vectors: 545000
# INFO:__main__:Adding batch 110/155 (from index 545000 to 549999)...
# INFO:__main__:Batch 110 added. Current total vectors: 550000
# INFO:__main__:Adding batch 111/155 (from index 550000 to 554999)...
# INFO:__main__:Batch 111 added. Current total vectors: 555000
# INFO:__main__:Adding batch 112/155 (from index 555000 to 559999)...
# INFO:__main__:Batch 112 added. Current total vectors: 560000
# INFO:__main__:Adding batch 113/155 (from index 560000 to 564999)...
# INFO:__main__:Batch 113 added. Current total vectors: 565000
# INFO:__main__:Adding batch 114/155 (from index 565000 to 569999)...
# INFO:__main__:Batch 114 added. Current total vectors: 570000
# INFO:__main__:Adding batch 115/155 (from index 570000 to 574999)...
# INFO:__main__:Batch 115 added. Current total vectors: 575000
# INFO:__main__:Adding batch 116/155 (from index 575000 to 579999)...
# INFO:__main__:Batch 116 added. Current total vectors: 580000
# INFO:__main__:Adding batch 117/155 (from index 580000 to 584999)...
# INFO:__main__:Batch 117 added. Current total vectors: 585000
# INFO:__main__:Adding batch 118/155 (from index 585000 to 589999)...
# INFO:__main__:Batch 118 added. Current total vectors: 590000
# INFO:__main__:Adding batch 119/155 (from index 590000 to 594999)...
# INFO:__main__:Batch 119 added. Current total vectors: 595000
# INFO:__main__:Adding batch 120/155 (from index 595000 to 599999)...
# INFO:__main__:Batch 120 added. Current total vectors: 600000
# INFO:__main__:Adding batch 121/155 (from index 600000 to 604999)...
# INFO:__main__:Batch 121 added. Current total vectors: 605000
# INFO:__main__:Adding batch 122/155 (from index 605000 to 609999)...
# INFO:__main__:Batch 122 added. Current total vectors: 610000
# INFO:__main__:Adding batch 123/155 (from index 610000 to 614999)...
# INFO:__main__:Batch 123 added. Current total vectors: 615000
# INFO:__main__:Adding batch 124/155 (from index 615000 to 619999)...
# INFO:__main__:Batch 124 added. Current total vectors: 620000
# INFO:__main__:Adding batch 125/155 (from index 620000 to 624999)...
# INFO:__main__:Batch 125 added. Current total vectors: 625000
# INFO:__main__:Adding batch 126/155 (from index 625000 to 629999)...
# INFO:__main__:Batch 126 added. Current total vectors: 630000
# INFO:__main__:Adding batch 127/155 (from index 630000 to 634999)...
# INFO:__main__:Batch 127 added. Current total vectors: 635000
# INFO:__main__:Adding batch 128/155 (from index 635000 to 639999)...
# INFO:__main__:Batch 128 added. Current total vectors: 640000
# INFO:__main__:Adding batch 129/155 (from index 640000 to 644999)...
# INFO:__main__:Batch 129 added. Current total vectors: 645000
# INFO:__main__:Adding batch 130/155 (from index 645000 to 649999)...
# INFO:__main__:Batch 130 added. Current total vectors: 650000
# INFO:__main__:Adding batch 131/155 (from index 650000 to 654999)...
# INFO:__main__:Batch 131 added. Current total vectors: 655000
# INFO:__main__:Adding batch 132/155 (from index 655000 to 659999)...
# INFO:__main__:Batch 132 added. Current total vectors: 660000
# INFO:__main__:Adding batch 133/155 (from index 660000 to 664999)...
# INFO:__main__:Batch 133 added. Current total vectors: 665000
# INFO:__main__:Adding batch 134/155 (from index 665000 to 669999)...
# INFO:__main__:Batch 134 added. Current total vectors: 670000
# INFO:__main__:Adding batch 135/155 (from index 670000 to 674999)...
# INFO:__main__:Batch 135 added. Current total vectors: 675000
# INFO:__main__:Adding batch 136/155 (from index 675000 to 679999)...
# INFO:__main__:Batch 136 added. Current total vectors: 680000
# INFO:__main__:Adding batch 137/155 (from index 680000 to 684999)...
# INFO:__main__:Batch 137 added. Current total vectors: 685000
# INFO:__main__:Adding batch 138/155 (from index 685000 to 689999)...
# INFO:__main__:Batch 138 added. Current total vectors: 690000
# INFO:__main__:Adding batch 139/155 (from index 690000 to 694999)...
# INFO:__main__:Batch 139 added. Current total vectors: 695000
# INFO:__main__:Adding batch 140/155 (from index 695000 to 699999)...
# INFO:__main__:Batch 140 added. Current total vectors: 700000
# INFO:__main__:Adding batch 141/155 (from index 700000 to 704999)...
# INFO:__main__:Batch 141 added. Current total vectors: 705000
# INFO:__main__:Adding batch 142/155 (from index 705000 to 709999)...
# INFO:__main__:Batch 142 added. Current total vectors: 710000
# INFO:__main__:Adding batch 143/155 (from index 710000 to 714999)...
# INFO:__main__:Batch 143 added. Current total vectors: 715000
# INFO:__main__:Adding batch 144/155 (from index 715000 to 719999)...
# INFO:__main__:Batch 144 added. Current total vectors: 720000
# INFO:__main__:Adding batch 145/155 (from index 720000 to 724999)...
# INFO:__main__:Batch 145 added. Current total vectors: 725000
# INFO:__main__:Adding batch 146/155 (from index 725000 to 729999)...
# INFO:__main__:Batch 146 added. Current total vectors: 730000
# INFO:__main__:Adding batch 147/155 (from index 730000 to 734999)...
# INFO:__main__:Batch 147 added. Current total vectors: 735000
# INFO:__main__:Adding batch 148/155 (from index 735000 to 739999)...
# INFO:__main__:Batch 148 added. Current total vectors: 740000
# INFO:__main__:Adding batch 149/155 (from index 740000 to 744999)...
# INFO:__main__:Batch 149 added. Current total vectors: 745000
# INFO:__main__:Adding batch 150/155 (from index 745000 to 749999)...
# INFO:__main__:Batch 150 added. Current total vectors: 750000
# INFO:__main__:Adding batch 151/155 (from index 750000 to 754999)...
# INFO:__main__:Batch 151 added. Current total vectors: 755000
# INFO:__main__:Adding batch 152/155 (from index 755000 to 759999)...
# INFO:__main__:Batch 152 added. Current total vectors: 760000
# INFO:__main__:Adding batch 153/155 (from index 760000 to 764999)...
# INFO:__main__:Batch 153 added. Current total vectors: 765000
# INFO:__main__:Adding batch 154/155 (from index 765000 to 769999)...
# INFO:__main__:Batch 154 added. Current total vectors: 770000
# INFO:__main__:Adding batch 155/155 (from index 770000 to 770307)...
# INFO:__main__:Batch 155 added. Current total vectors: 770308
# INFO:__main__:Indexed 770308 vectors in ChromaDB
# Total vectors in collection: 770308

# %%
# Optional: Test similarity search
query_text = "issue on "
query_embedding = model.encode([query_text], convert_to_numpy=True)[0]

results = collection.query(
    query_embeddings=[query_embedding.tolist()],
    n_results=5
)

print("\nTop 5 similar chunks:")
for i, doc in enumerate(results['documents'][0]):
    complaint_id = results['metadatas'][0][i]['complaint_id']
    mapped_product = results['metadatas'][0][i]['mapped_product']
    print(f"Rank {i+1}: Complaint ID = {complaint_id}, Product = {mapped_product}, Chunk = {doc[:100]}...")
